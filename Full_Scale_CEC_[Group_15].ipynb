# %% [markdown]
# <a href="https://colab.research.google.com/github/WinNatch/UoB-Modelling-Analytics--Group-15/blob/main/Full_Scale_CEC_%5BGroup_15%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DEA - Main Dataset**

# %%
# !pip install pulp
import pulp
# !apt-get install -y -qq glpk-utils
from pulp import GLPK
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/WinNatch/UoB-Modelling-Analytics--Group-15/main/DEA_Main.csv'
data = pd.read_csv(url)

list_objective_values=[]
weights_matrix = np.empty((14,9))
for k in range(9):
    dea_model = pulp.LpProblem("F1_Analysis", pulp.LpMaximize)
    m1 = pulp.LpVariable("u1", lowBound=0, upBound=None, cat='Continuous')
    m2 = pulp.LpVariable("u2", lowBound=0, upBound=None, cat='Continuous')
    m3 = pulp.LpVariable("u3", lowBound=0, upBound=None, cat='Continuous')
    m4 = pulp.LpVariable("u4", lowBound=0, upBound=None, cat='Continuous')
    m5 = pulp.LpVariable("u5", lowBound=0, upBound=None, cat='Continuous')
    m6 = pulp.LpVariable("u6", lowBound=0, upBound=None, cat='Continuous')
    n1 = pulp.LpVariable("v1", lowBound=0, upBound=None, cat='Continuous')
    n2 = pulp.LpVariable("v2", lowBound=0, upBound=None, cat='Continuous')
    n3 = pulp.LpVariable("v3", lowBound=0, upBound=None, cat='Continuous')
    n4 = pulp.LpVariable("v4", lowBound=0, upBound=None, cat='Continuous')
    n5 = pulp.LpVariable("v5", lowBound=0, upBound=None, cat='Continuous')
    n6 = pulp.LpVariable("v6", lowBound=0, upBound=None, cat='Continuous')
    n7 = pulp.LpVariable("v7", lowBound=0, upBound=None, cat='Continuous')
    n8 = pulp.LpVariable("v8", lowBound=0, upBound=None, cat='Continuous')

    # Objective Function
    dea_model += m1*data["Y1"][k] + m2*data["Y2"][k] + m3*data["Y3"][k] + m4*data["Y4"][k] + m5*data["Y5"][k] + m6*data["Y6"][k]

    # Constraint
    dea_model += n1*data["X1"][k] + n2*data["X2"][k] + n3*data["X3"][k] + n4*data["X4"][k] + n5*data["X5"][k] + n6*data["X6"][k] + n7*data["X7"][k] + n8*data["X8"][k] == 1

    for i in range(9):
        dea_model += m1*data["Y1"][i] + m2*data["Y2"][i] + m3*data["Y3"][i] + m4*data["Y4"][i] + m5*data["Y5"][i] + m6*data["Y6"][i] - n1*data["X1"][i] - n2*data["X2"][i] - n3*data["X3"][i] - n4*data["X4"][i] - n5*data["X5"][i] - n6*data["X6"][i] - n7*data["X7"][i] - n8*data["X8"][i] <= 0

    # Solve The Model
    status = dea_model.solve()
    print("Model Status:{}".format(pulp.LpStatus[dea_model.status]))

    # Save Variables in Matrix
    list_weights=[]
    for v in dea_model.variables():
	      print(v.name, "=", v.varValue)
    for v in dea_model.variables():
        list_weights = list_weights + [v.varValue]
    for n in range(14):
        value = list_weights[n]
        weights_matrix[n,k] = value

    list_objective_values.append(pulp.value(dea_model.objective))
    print("Objective=", pulp.value(dea_model.objective))

    print("\nConstraint")
    for name, c in dea_model.constraints.items():
	      print(name, ":", c)
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 45.9 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# (Reading database ... 123630 files and directories currently installed.)
# Preparing to unpack .../libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../libglpk40_5.0-1_amd64.deb ...
# Unpacking libglpk40:amd64 (5.0-1) ...
# Selecting previously unselected package glpk-utils.
# Preparing to unpack .../glpk-utils_5.0-1_amd64.deb ...
# Unpacking glpk-utils (5.0-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libglpk40:amd64 (5.0-1) ...
# Setting up glpk-utils (5.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.00032643822
# u4 = 0.0
# u5 = 0.0
# u6 = 0.90904688
# v1 = 0.0
# v2 = 0.0
# v3 = 0.0
# v4 = 0.03608592
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.025763719
# Objective= 0.9743815959800001
#
# Constraint
# _C1 : 190*v1 + 380*v2 + 43*v3 + 22*v4 + 1.099*v5 + 478*v6 + 1000*v7 + 8*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.0
# u4 = 0.05
# u5 = 0.0
# u6 = 0.0
# v1 = 0.0
# v2 = 0.0
# v3 = 0.015384615
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.0
# Objective= 1.0
#
# Constraint
# _C1 : 180*v1 + 380*v2 + 65*v3 + 25*v4 + v5 + 486*v6 + 1040*v7 + 10*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.00073325415
# u4 = 0.0
# u5 = 0.0
# u6 = 0.78556914
# v1 = 0.0
# v2 = 0.0011283426
# v3 = 4.2389582e-06
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.096119822
# Objective= 0.99999999606
#
# Constraint
# _C1 : 180*v1 + 375*v2 + 36*v3 + 23*v4 + 1.316*v5 + 351*v6 + 1050*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.0012792019
# u4 = 0.0
# u5 = 0.13767958
# u6 = 0.2200025
# v1 = 0.0
# v2 = 0.0
# v3 = 0.037514425
# v4 = 0.0
# v5 = 0.0
# v6 = 0.00047454402
# v7 = 0.0
# v8 = 0.015826543
# Objective= 0.9999999937999999
#
# Constraint
# _C1 : 160*v1 + 320*v2 + 22*v3 + 22*v4 + 1.064*v5 + 168*v6 + 1000*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.064062121
# u3 = 0.0
# u4 = 0.0
# u5 = 0.48750303
# u6 = 0.0
# v1 = 0.0016500849
# v2 = 0.0
# v3 = 0.10749818
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.0
# Objective= 0.9999999980000001
#
# Constraint
# _C1 : 150*v1 + 260*v2 + 7*v3 + 23*v4 + 1.087*v5 + 566*v6 + 740*v7 + 10*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.00036409597
# u4 = 0.0
# u5 = 0.0
# u6 = 0.93174631
# v1 = 0.0
# v2 = 0.0
# v3 = 0.0
# v4 = 0.033617474
# v5 = 0.0
# v6 = 3.3053612e-05
# v7 = 0.0
# v8 = 0.035762033
# Objective= 0.9102155847000001
#
# Constraint
# _C1 : 140*v1 + 240*v2 + 11*v3 + 22*v4 + 1.176*v5 + 305*v6 + 950*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.010530587
# u4 = 0.0
# u5 = 0.0
# u6 = 0.054424102
# v1 = 0.0
# v2 = 0.0
# v3 = 0.11747985
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0038411639
# v7 = 0.0
# v8 = 0.0
# Objective= 0.9999999679199999
#
# Constraint
# _C1 : 100*v1 + 205*v2 + 4*v3 + 20*v4 + 1.19*v5 + 138*v6 + 1000*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.0
# u4 = 0.0
# u5 = 0.0
# u6 = 1.0471204
# v1 = 0.0
# v2 = 0.0058823529
# v3 = 0.0
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.0
# Objective= 0.9916230188
#
# Constraint
# _C1 : 100*v1 + 170*v2 + 7*v3 + 20*v4 + 1.064*v5 + 410*v6 + 1050*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# Model Status:Optimal
# u1 = 0.0
# u2 = 0.0
# u3 = 0.0054859869
# u4 = 0.0
# u5 = 0.027628702
# u6 = 0.87457762
# v1 = 0.0
# v2 = 0.0
# v3 = 0.33333333
# v4 = 0.0
# v5 = 0.0
# v6 = 0.0
# v7 = 0.0
# v8 = 0.0
# Objective= 1.0000000016
#
# Constraint
# _C1 : 100*v1 + 170*v2 + 3*v3 + 20*v4 + 1.053*v5 + 363*v6 + 540*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0

# %%
weights_matrix
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         6.4062121e-02, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [3.2643822e-04, 0.0000000e+00, 7.3325415e-04, 1.2792019e-03,
#         0.0000000e+00, 3.6409597e-04, 1.0530587e-02, 0.0000000e+00,
#         5.4859869e-03],
#        [0.0000000e+00, 5.0000000e-02, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3767958e-01,
#         4.8750303e-01, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         2.7628702e-02],
#        [9.0904688e-01, 0.0000000e+00, 7.8556914e-01, 2.2000250e-01,
#         0.0000000e+00, 9.3174631e-01, 5.4424102e-02, 1.0471204e+00,
#         8.7457762e-01],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.6500849e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 1.1283426e-03, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.8823529e-03,
#         0.0000000e+00],
#        [0.0000000e+00, 1.5384615e-02, 4.2389582e-06, 3.7514425e-02,
#         1.0749818e-01, 0.0000000e+00, 1.1747985e-01, 0.0000000e+00,
#         3.3333333e-01],
#        [3.6085920e-02, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 3.3617474e-02, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.7454402e-04,
#         0.0000000e+00, 3.3053612e-05, 3.8411639e-03, 0.0000000e+00,
#         0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [2.5763719e-02, 0.0000000e+00, 9.6119822e-02, 1.5826543e-02,
#         0.0000000e+00, 3.5762033e-02, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00]])

# %% [markdown]
# **FULL SCALE CONSENSUS CROSS-EFFICIENCY**

# %%
list_objective_values
# Out:
# [0.9743815959800001,
#  1.0,
#  0.99999999606,
#  0.9999999937999999,
#  0.9999999980000001,
#  0.9102155847000001,
#  0.9999999679199999,
#  0.9916230188,
#  1.0000000016]

# %%
# Calculate New Weights using Second Objective Model
CEC_weights_matrix = np.empty((14,9))
for k in range(9):
    Second_Objective_model = pulp.LpProblem("F1_Analysis_CEC", pulp.LpMaximize)
    y1 = pulp.LpVariable("u1", lowBound=0, upBound=None, cat='Continuous')
    y2 = pulp.LpVariable("u2", lowBound=0, upBound=None, cat='Continuous')
    y3 = pulp.LpVariable("u3", lowBound=0, upBound=None, cat='Continuous')
    y4 = pulp.LpVariable("u4", lowBound=0, upBound=None, cat='Continuous')
    y5 = pulp.LpVariable("u5", lowBound=0, upBound=None, cat='Continuous')
    y6 = pulp.LpVariable("u6", lowBound=0, upBound=None, cat='Continuous')
    x1 = pulp.LpVariable("v1", lowBound=0, upBound=None, cat='Continuous')
    x2 = pulp.LpVariable("v2", lowBound=0, upBound=None, cat='Continuous')
    x3 = pulp.LpVariable("v3", lowBound=0, upBound=None, cat='Continuous')
    x4 = pulp.LpVariable("v4", lowBound=0, upBound=None, cat='Continuous')
    x5 = pulp.LpVariable("v5", lowBound=0, upBound=None, cat='Continuous')
    x6 = pulp.LpVariable("v6", lowBound=0, upBound=None, cat='Continuous')
    x7 = pulp.LpVariable("v7", lowBound=0, upBound=None, cat='Continuous')
    x8 = pulp.LpVariable("v8", lowBound=0, upBound=None, cat='Continuous')

    # Define the objective function
    Second_Objective_model += (y1*data["Y1"].sum() + y2*data["Y2"].sum() + y3*data["Y3"].sum() + y4*data["Y4"].sum() + y5*data["Y5"].sum() + y6*data["Y6"].sum()) - (x1*data["X1"].sum() + x2*data["X2"].sum() + x3*data["X3"].sum() + x4*data["X4"].sum() + x5*data["X5"].sum() + x6*data["X6"].sum() + x7*data["X7"].sum() + x8*data["X8"].sum())

    # Constraint
    Second_Objective_model += x1*data["X1"][k] + x2*data["X2"][k] + x3*data["X3"][k] + x4*data["X4"][k] + x5*data["X5"][k] + x6*data["X6"][k] + x7*data["X7"][k] + x8*data["X8"][k] == 1

    for j in range(9):
        Second_Objective_model += y1*data["Y1"][j] + y2*data["Y2"][j] + y3*data["Y3"][j] + y4*data["Y4"][j] + y5*data["Y5"][j] + y6*data["Y6"][j] - x1*data["X1"][j] - x2*data["X2"][j] - x3*data["X3"][j] - x4*data["X4"][j] - x5*data["X5"][j] - x6*data["X6"][j] - x7*data["X7"][j] - x8*data["X8"][j] <= 0

    Second_Objective_model += y1*data["Y1"][k] + y2*data["Y2"][k] + y3*data["Y3"][k] + y4*data["Y4"][k] + y5*data["Y5"][k] + y6*data["Y6"][k] - (list_objective_values[k] * (x1*data["X1"][k] + x2*data["X2"][k] + x3*data["X3"][k] + x4*data["X4"][k] + x5*data["X5"][k] + x6*data["X6"][k] + x7*data["X7"][k] + x8*data["X8"][k])) == 0

    # Solve The Model
    status = Second_Objective_model.solve()
    print("Model Status:{}".format(pulp.LpStatus[Second_Objective_model.status]))

    # Save Variables in Matrix
    new_list_weights=[]
    for v in Second_Objective_model.variables():
        v.varValue = max(0, v.varValue)
    for v in Second_Objective_model.variables():
	      print(v.name, "=", v.varValue)
    for v in Second_Objective_model.variables():
        new_list_weights = new_list_weights + [v.varValue]
    for n in range(14):
        value = new_list_weights[n]
        CEC_weights_matrix[n,k] = value

    print("\nConstraint")
    for name, c in Second_Objective_model.constraints.items():
	      print(name, ":", c)
# Out:
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.0003264382
# u4 = 0
# u5 = 0
# u6 = 0.90904689
# v1 = 0
# v2 = 0
# v3 = 0
# v4 = 0.036085921
# v5 = 0
# v6 = 1.1458961e-13
# v7 = 0
# v8 = 0.025763718
#
# Constraint
# _C1 : 190*v1 + 380*v2 + 43*v3 + 22*v4 + 1.099*v5 + 478*v6 + 1000*v7 + 8*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 185.13250323620002*v1 - 370.26500647240005*v2 - 41.89840862714*v3 - 21.436395111560003*v4 - 1.07084537398202*v5 - 465.75440287844003*v6 - 974.38159598*v7 - 7.795052767840001*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00071090488
# u4 = 0
# u5 = 0
# u6 = 0.40188397
# v1 = 0
# v2 = 0
# v3 = 0.0070566202
# v4 = 0.011915733
# v5 = 0
# v6 = 0
# v7 = 4.724433e-05
# v8 = 0.019429225
#
# Constraint
# _C1 : 180*v1 + 380*v2 + 65*v3 + 25*v4 + v5 + 486*v6 + 1040*v7 + 10*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180.0*v1 - 380.0*v2 - 65.0*v3 - 25.0*v4 - v5 - 486.0*v6 - 1040.0*v7 - 10.0*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00044380416
# u4 = 0
# u5 = 0
# u6 = 0.91701958
# v1 = 0
# v2 = 0
# v3 = 0
# v4 = 0.026287709
# v5 = 0
# v6 = 0
# v7 = 6.7231506e-05
# v8 = 0.054131603
#
# Constraint
# _C1 : 180*v1 + 375*v2 + 36*v3 + 23*v4 + 1.316*v5 + 351*v6 + 1050*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 179.9999992908*v1 - 374.9999985225*v2 - 35.99999985816*v3 - 22.99999990938*v4 - 1.31599999481496*v5 - 350.99999861706*v6 - 1049.999995863*v7 - 5.99999997636*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00054986275
# u4 = 0
# u5 = 0
# u6 = 0.91440948
# v1 = 0
# v2 = 0
# v3 = 0.0025118909
# v4 = 0.032633227
# v5 = 0
# v6 = 0
# v7 = 0
# v8 = 0.037801235
#
# Constraint
# _C1 : 160*v1 + 320*v2 + 22*v3 + 22*v4 + 1.064*v5 + 168*v6 + 1000*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 159.99999900799997*v1 - 319.99999801599995*v2 - 21.9999998636*v3 - 21.9999998636*v4 - 1.0639999934032*v5 - 167.9999989584*v6 - 999.9999938*v7 - 5.9999999628*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.0010411018
# u4 = 0
# u5 = 0
# u6 = 0.80510397
# v1 = 0
# v2 = 0
# v3 = 0.011420482
# v4 = 0.016969423
# v5 = 0.25797403
# v6 = 0
# v7 = 0
# v8 = 0.024934211
#
# Constraint
# _C1 : 150*v1 + 260*v2 + 7*v3 + 23*v4 + 1.087*v5 + 566*v6 + 740*v7 + 10*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 149.99999970000002*v1 - 259.99999948000004*v2 - 6.999999986000001*v3 - 22.999999954*v4 - 1.086999997826*v5 - 565.999998868*v6 - 739.9999985200001*v7 - 9.99999998*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00036409591
# u4 = 0
# u5 = 0
# u6 = 0.93174632
# v1 = 0
# v2 = 0
# v3 = 0
# v4 = 0.033617481
# v5 = 0
# v6 = 3.3053546e-05
# v7 = 0
# v8 = 0.035762014
#
# Constraint
# _C1 : 140*v1 + 240*v2 + 11*v3 + 22*v4 + 1.176*v5 + 305*v6 + 950*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 2*u2 + 120*u3 + 0.93*u6 - 127.43018185800001*v1 - 218.45174032800003*v2 - 10.0123714317*v3 - 20.0247428634*v4 - 1.0704135276072*v5 - 277.61575333350004*v6 - 864.704805465*v7 - 6.3715090929*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00039266425
# u4 = 0
# u5 = 0
# u6 = 1.0048544
# v1 = 0
# v2 = 0
# v3 = 0
# v4 = 0.036255214
# v5 = 0
# v6 = 3.5647025e-05
# v7 = 0
# v8 = 0.038568061
#
# Constraint
# _C1 : 100*v1 + 205*v2 + 4*v3 + 20*v4 + 1.19*v5 + 138*v6 + 1000*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : u2 + 90*u3 + 0.96*u6 - 99.99999679199999*v1 - 204.9999934236*v2 - 3.9999998716799996*v3 - 19.999999358399997*v4 - 1.1899999618247998*v5 - 137.99999557296*v6 - 999.9999679199999*v7 - 6.999999775439999*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0.010410331
# u3 = 0
# u4 = 0
# u5 = 0
# u6 = 1.0471204
# v1 = 0
# v2 = 0.00044702025
# v3 = 0
# v4 = 0.046200241
# v5 = 1.6363636e-06
# v6 = 0
# v7 = 0
# v8 = 0
#
# Constraint
# _C1 : 100*v1 + 170*v2 + 7*v3 + 20*v4 + 1.064*v5 + 410*v6 + 1050*v7 + 7*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 12*u3 + 0.947*u6 - 99.16230188*v1 - 168.57591319600002*v2 - 6.9413611316*v3 - 19.832460376*v4 - 1.0550868920032002*v5 - 406.565437708*v6 - 1041.20416974*v7 - 6.9413611316*v8 = -0.0
# Model Status:Optimal
# u1 = 0
# u2 = 0
# u3 = 0.00040503707
# u4 = 0
# u5 = 0
# u6 = 1.0365174
# v1 = 0
# v2 = 0
# v3 = 0
# v4 = 0.03739762
# v5 = 0
# v6 = 3.677035e-05
# v7 = 0
# v8 = 0.039783326
#
# Constraint
# _C1 : 100*v1 + 170*v2 + 3*v3 + 20*v4 + 1.053*v5 + 363*v6 + 540*v7 + 6*v8 = 1.0
# _C2 : 8*u2 + 409*u3 + 2*u4 + 5*u5 + 0.925*u6 - 190*v1 - 380*v2 - 43*v3 - 22*v4 - 1.099*v5 - 478*v6 - 1000*v7 - 8*v8 <= -0.0
# _C3 : 21*u1 + 30*u2 + 860*u3 + 20*u4 + 11*u5 + 0.967*u6 - 180*v1 - 380*v2 - 65*v3 - 25*v4 - v5 - 486*v6 - 1040*v7 - 10*v8 <= -0.0
# _C4 : u1 + 9*u2 + 406*u3 + 2*u4 + 0.894*u6 - 180*v1 - 375*v2 - 36*v3 - 23*v4 - 1.316*v5 - 351*v6 - 1050*v7 - 6*v8 <= -0.0
# _C5 : 9*u2 + 302*u3 + u4 + 3*u5 + 0.912*u6 - 160*v1 - 320*v2 - 22*v3 - 22*v4 - 1.064*v5 - 168*v6 - 1000*v7 - 6*v8 <= -0.0
# _C6 : 8*u2 + 280*u3 + u5 + 0.88*u6 - 150*v1 - 260*v2 - 7*v3 - 23*v4 - 1.087*v5 - 566*v6 - 740*v7 - 10*v8 <= -0.0
# _C7 : 2*u2 + 120*u3 + 0.93*u6 - 140*v1 - 240*v2 - 11*v3 - 22*v4 - 1.176*v5 - 305*v6 - 950*v7 - 7*v8 <= -0.0
# _C8 : u2 + 90*u3 + 0.96*u6 - 100*v1 - 205*v2 - 4*v3 - 20*v4 - 1.19*v5 - 138*v6 - 1000*v7 - 7*v8 <= -0.0
# _C9 : 12*u3 + 0.947*u6 - 100*v1 - 170*v2 - 7*v3 - 20*v4 - 1.064*v5 - 410*v6 - 1050*v7 - 7*v8 <= -0.0
# _C10 : 25*u3 + u5 + 0.955*u6 - 100*v1 - 170*v2 - 3*v3 - 20*v4 - 1.053*v5 - 363*v6 - 540*v7 - 6*v8 <= -0.0
# _C11 : 25*u3 + u5 + 0.955*u6 - 100.00000015999998*v1 - 170.000000272*v2 - 3.0000000047999995*v3 - 20.000000032*v4 - 1.0530000016847998*v5 - 363.00000058079996*v6 - 540.000000864*v7 - 6.000000009599999*v8 = -0.0

# %%
CEC_weights_matrix

df1 = pd.DataFrame(CEC_weights_matrix)
df1.to_csv("Input&Output_Weight_CEC.csv", index=False)

# %%
# Create New Cross Efficiency Table and Calculate New CITE Score
new_cross_efficiency_table = np.empty((9,9))
for row in range(9):
    row_values = []
    for column in range(9):
        new_value = ((CEC_weights_matrix[0,column]*data["Y1"][row])+(CEC_weights_matrix[1,column]*data["Y2"][row])+(CEC_weights_matrix[2,column]*data["Y3"][row])+(CEC_weights_matrix[3,column]*data["Y4"][row])+(CEC_weights_matrix[4,column]*data["Y5"][row])+(CEC_weights_matrix[5,column]*data["Y6"][row]))/((CEC_weights_matrix[6,column]*data["X1"][row])+(CEC_weights_matrix[7,column]*data["X2"][row])+(CEC_weights_matrix[8,column]*data["X3"][row])+(CEC_weights_matrix[9,column]*data["X4"][row])+(CEC_weights_matrix[10,column]*data["X5"][row])+(CEC_weights_matrix[11,column]*data["X6"][row])+(CEC_weights_matrix[12,column]*data["X7"][row])+(CEC_weights_matrix[13,column]*data["X8"][row]))
        new_cross_efficiency_table[row,column] = new_value
        row_values += [new_value]

F1_Teams = data['F1-Team'].tolist()

new_cross_efficiency = new_cross_efficiency_table.round(decimals=2)

CEC_cross_efficiency_table = pd.DataFrame(new_cross_efficiency)
CEC_cross_efficiency_table.insert(0, 'F1-Teams', F1_Teams)
set_column_names = ['F1-Teams'] + [team + " weight" for team in F1_Teams]
CEC_cross_efficiency_table.columns = set_column_names

display(CEC_cross_efficiency_table)
# Out:
#        F1-Teams  Mercedes weight  Red Bull weight  Ferrari weight  \
# 0      Mercedes             0.97             0.86            0.95
# 1      Red Bull             1.00             1.00            1.00
# 2       Ferrari             0.96             0.93            1.00
# 3       McLaren             0.98             1.00            1.00
# 4  Aston Martin             0.82             1.00            0.78
# 5        Alpine             0.91             0.88            0.89
# 6      Williams             1.00             1.00            0.95
# 7          Haas             0.96             0.82            0.90
# 8    AlphaTauri             1.00             1.00            1.00
#
#    McLaren weight  Aston Martin weight  Alpine weight  Williams weight  \
# 0            0.95                 0.87           0.97             0.97
# 1            1.00                 1.00           1.00             1.00
# 2            0.97                 0.89           0.98             0.98
# 3            1.00                 1.00           1.00             1.00
# 4            0.84                 1.00           0.80             0.80
# 5            0.91                 0.89           0.91             0.91
# 6            1.00                 1.00           1.00             1.00
# 7            0.93                 0.89           0.95             0.95
# 8            1.00                 1.00           1.00             1.00
#
#    Haas weight  AlphaTauri weight
# 0         0.89               0.97
# 1         1.00               1.00
# 2         0.84               0.98
# 3         0.90               1.00
# 4         0.85               0.80
# 5         0.89               0.91
# 6         1.00               1.00
# 7         0.99               0.95
# 8         1.00               1.00

# %%
new_cross_efficiency
# Out:
# array([[0.97, 0.86, 0.95, 0.95, 0.87, 0.97, 0.97, 0.89, 0.97],
#        [1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ],
#        [0.96, 0.93, 1.  , 0.97, 0.89, 0.98, 0.98, 0.84, 0.98],
#        [0.98, 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 0.9 , 1.  ],
#        [0.82, 1.  , 0.78, 0.84, 1.  , 0.8 , 0.8 , 0.85, 0.8 ],
#        [0.91, 0.88, 0.89, 0.91, 0.89, 0.91, 0.91, 0.89, 0.91],
#        [1.  , 1.  , 0.95, 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ],
#        [0.96, 0.82, 0.9 , 0.93, 0.89, 0.95, 0.95, 0.99, 0.95],
#        [1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ]])

# %%
# Set a DMU as CRP (Comparative Reference Point)
CEC_CRP_DMU = new_cross_efficiency[1]

# Rescaling by divide each column by the corresponding value in CRP row
CEC_Rescale_Matrix = np.zeros_like(new_cross_efficiency)
for i in range(new_cross_efficiency.shape[1]):
    CEC_Rescale_Matrix[:, i] = new_cross_efficiency[:, i] / CEC_CRP_DMU[i]

CEC_Rescale_Matrix = np.round(CEC_Rescale_Matrix, 2)

CEC_Rescale_Matrix
# Out:
# array([[0.97, 0.86, 0.95, 0.95, 0.87, 0.97, 0.97, 0.89, 0.97],
#        [1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ],
#        [0.96, 0.93, 1.  , 0.97, 0.89, 0.98, 0.98, 0.84, 0.98],
#        [0.98, 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 0.9 , 1.  ],
#        [0.82, 1.  , 0.78, 0.84, 1.  , 0.8 , 0.8 , 0.85, 0.8 ],
#        [0.91, 0.88, 0.89, 0.91, 0.89, 0.91, 0.91, 0.89, 0.91],
#        [1.  , 1.  , 0.95, 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ],
#        [0.96, 0.82, 0.9 , 0.93, 0.89, 0.95, 0.95, 0.99, 0.95],
#        [1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  , 1.  ]])

# %%
import math

# Fixing the value of zero (in the case that have)

# Compute geometric mean for each DMU (rows)
geometric_mean = [math.prod(CEC_Rescale_Matrix[i, :]) ** (1 / CEC_Rescale_Matrix.shape[1]) for i in range(CEC_Rescale_Matrix.shape[0])]

# Initialize diviation as a list to store the values
root_sum_squared_list = []

# Iterate over each column
for col in range(CEC_Rescale_Matrix.shape[1]):
  column = CEC_Rescale_Matrix[:, col]  # Select the current column
  mean = geometric_mean[col]  # Access corresponding geometric mean

  # Calculate square root of squared deviations and sum
  deviations = math.sqrt(sum((x - mean)**2 for x in column))

  # Append the root of sum of squared deviations for the column
  root_sum_squared_list.append(deviations)

# Convert the string values to float
root_sum_squared_list = [float(x) for x in root_sum_squared_list]

root_sum_squared_list
# Out:
# [0.17915226086210337,
#  0.26702059845637377,
#  0.21105755416764527,
#  0.1806761475695104,
#  0.3407592144187738,
#  0.2529345596180697,
#  0.21853580464616798,
#  0.1923481991087423,
#  0.2278157149978903]

# %%
# Calculate ECD (Evaluation Consensus Degree) for each value
ECD = [1 / (1 + x) for x in root_sum_squared_list]

ECD
# Out:
# [0.8480668978821094,
#  0.7892531512260431,
#  0.825724588033552,
#  0.8469723065537974,
#  0.7458460767942626,
#  0.7981262806772834,
#  0.8206570510173681,
#  0.8386811845293858,
#  0.8144544721043241]

# %%
import numpy as np

# Calculate the sum of ECD
total_power = sum(ECD)

# Calculate the CEC score for each DMU
CEC_Results = []
for i in range(len(ECD)):
  row = CEC_Rescale_Matrix[i]
  product = np.prod(np.power(row, ECD[i]))
  result = np.power(product, 1/total_power)
  CEC_Results.append(result)

CEC_Results = np.array(CEC_Results)

for team in F1_Teams:
    index = F1_Teams.index(team)
    print("CEC score for",team,"=",CEC_Results[index])
# Out:
# CEC score for Mercedes = 0.9295706496105759
# CEC score for Red Bull = 1.0
# CEC score for Ferrari = 0.945711466409036
# CEC score for McLaren = 0.9855917424325874
# CEC score for Aston Martin = 0.8625060689026678
# CEC score for Alpine = 0.9018006801319312
# CEC score for Williams = 0.9942720006613559
# CEC score for Haas = 0.9232551039684014
# CEC score for AlphaTauri = 1.0

# %% [markdown]
# **Cross Efficiency & Arithmetic Cross-efficiency**

# %%
from statistics import mean
import pandas as pd

# Create Cross Efficiency Table and Calculate Calculate CITE Score
cross_efficiency_table = np.empty((9,9))
avg_efficiency = []
for row in range(9):
    row_values = []
    for column in range(9):
        value = ((weights_matrix[0,column]*data["Y1"][row])+(weights_matrix[1,column]*data["Y2"][row])+(weights_matrix[2,column]*data["Y3"][row])+(weights_matrix[3,column]*data["Y4"][row])+(weights_matrix[4,column]*data["Y5"][row])+(weights_matrix[5,column]*data["Y6"][row]))/((weights_matrix[6,column]*data["X1"][row])+(weights_matrix[7,column]*data["X2"][row])+(weights_matrix[8,column]*data["X3"][row])+(weights_matrix[9,column]*data["X4"][row])+(weights_matrix[10,column]*data["X5"][row])+(weights_matrix[11,column]*data["X6"][row])+(weights_matrix[12,column]*data["X7"][row])+(weights_matrix[13,column]*data["X8"][row]))
        cross_efficiency_table[row,column] = value
        row_values += [value]

    # Calculate Arithmetic mean of Cross-efficiency score
    average = mean(row_values)
    avg_efficiency += [average]

average_list_rounded = [ '%.3f' % elem for elem in avg_efficiency ]

F1_Teams = data['F1-Team'].tolist()

for team in F1_Teams:
    index = F1_Teams.index(team)
    print("Arithmetic Cross-efficiency score for",team,"=",average_list_rounded[index])

F1_cross_efficiency = cross_efficiency_table.round(decimals=2)

F1_cross_efficiency_table = pd.DataFrame(F1_cross_efficiency)
F1_cross_efficiency_table.insert(0, 'F1-Teams', F1_Teams)
set_column_names = ['F1-Teams'] + [team + " weight" for team in F1_Teams]
F1_cross_efficiency_table.columns = set_column_names

display(F1_cross_efficiency_table)

F1_cross_efficiency_table.to_csv("Cross_Eff_DEA_Result.csv", index=False)
# Out:
# Arithmetic Cross-efficiency score for Mercedes = 0.618
# Arithmetic Cross-efficiency score for Red Bull = 0.854
# Arithmetic Cross-efficiency score for Ferrari = 0.573
# Arithmetic Cross-efficiency score for McLaren = 0.751
# Arithmetic Cross-efficiency score for Aston Martin = 0.771
# Arithmetic Cross-efficiency score for Alpine = 0.549
# Arithmetic Cross-efficiency score for Williams = 0.761
# Arithmetic Cross-efficiency score for Haas = 0.513
# Arithmetic Cross-efficiency score for AlphaTauri = 0.798
#        F1-Teams  Mercedes weight  Red Bull weight  Ferrari weight  \
# 0      Mercedes             0.97             0.15            0.86
# 1      Red Bull             1.00             1.00            1.00
# 2       Ferrari             0.96             0.18            1.00
# 3       McLaren             0.98             0.15            1.00
# 4  Aston Martin             0.82             0.00            0.71
# 5        Alpine             0.91             0.00            0.87
# 6      Williams             1.00             0.00            0.91
# 7          Haas             0.96             0.00            0.87
# 8    AlphaTauri             1.00             0.00            1.00
#
#    McLaren weight  Aston Martin weight  Alpine weight  Williams weight  \
# 0            0.72                 0.60           0.97             0.63
# 1            1.00                 1.00           1.00             0.96
# 2            0.44                 0.14           0.98             0.78
# 3            1.00                 0.78           1.00             1.00
# 4            1.00                 1.00           0.80             1.00
# 5            0.54                 0.09           0.91             0.53
# 6            1.00                 0.11           1.00             1.00
# 7            0.39                 0.00           0.95             0.07
# 8            1.00                 1.00           1.00             0.18
#
#    Haas weight  AlphaTauri weight
# 0         0.43               0.22
# 1         0.45               0.27
# 2         0.42               0.25
# 3         0.51               0.35
# 4         0.60               1.00
# 5         0.69               0.40
# 6         0.83               1.00
# 7         0.99               0.38
# 8         1.00               1.00

# %% [markdown]
# **GEOMETRIC MEAN CROSS-EFFICIENCY**

# %%
import math
import numpy as np

# Convert to a numpy array for convenience
matrix = np.array(F1_cross_efficiency)

# Fixing the zero efficiency score
matrix[4,1] = 1e-6
matrix[5,1] = 1e-6
matrix[6,1] = 1e-6
matrix[7,1] = 1e-6
matrix[8,1] = 1e-6
matrix[7,4] = 1e-6

# Compute geometric mean for each DMU (rows)
geometric_means = [math.prod(matrix[i, :]) ** (1 / matrix.shape[1]) for i in range(matrix.shape[0])]

# Display results
for dmu, gm in enumerate(geometric_means, start=0):
    team_name = F1_Teams[dmu]
    print(f"Geometric Mean efficiency for {team_name}: {round(gm, 3):.3f}")
# Out:
# Geometric Mean efficiency for Mercedes: 0.527
# Geometric Mean efficiency for Red Bull: 0.788
# Geometric Mean efficiency for Ferrari: 0.456
# Geometric Mean efficiency for McLaren: 0.649
# Geometric Mean efficiency for Aston Martin: 0.187
# Geometric Mean efficiency for Alpine: 0.120
# Geometric Mean efficiency for Williams: 0.163
# Geometric Mean efficiency for Haas: 0.027
# Geometric Mean efficiency for AlphaTauri: 0.178

# %% [markdown]
# **RESULT DISPLAY**

# %%
Sum_Result = [avg_efficiency, geometric_means, CEC_Results]

# Create a DataFrame with 3 columns, matching the length of data
final_result_table = pd.DataFrame(Sum_Result).transpose()

# Define column names matching the number of columns in the DataFrame (3)
column_names = ['Arithmetic', 'Geometric', 'Consensus']

# Assign the column names to the DataFrame
final_result_table.columns = column_names

# Set the row names (index) to F1_Teams
final_result_table.index = F1_Teams

final_result_table.to_csv("Main_Result_Final.csv", index=False)

final_result_table
# Out:
#               Arithmetic  Geometric  Consensus
# Mercedes        0.617647   0.526805   0.929571
# Red Bull        0.853593   0.787619   1.000000
# Ferrari         0.572775   0.456111   0.945711
# McLaren         0.750521   0.649141   0.985592
# Aston Martin    0.770965   0.186988   0.862506
# Alpine          0.548532   0.119902   0.901801
# Williams        0.760927   0.163410   0.994272
# Haas            0.513243   0.027200   0.923255
# AlphaTauri      0.797830   0.178068   1.000000
